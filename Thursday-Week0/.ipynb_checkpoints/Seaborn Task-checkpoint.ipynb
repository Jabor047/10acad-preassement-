# %% [markdown]
# # Seaborn Tasks

# %% [markdown]
# ## Tasks 1

# %% [markdown]
# Import the pandas_tasks.csv

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('pandas_tasks.csv')
df.head()
# Out:
#      ID  Q1  Q2  Q3  Q4  Q5  Q6  Q7  Q8_1  Q8_2  ...  Q17  Q18  Q19  Latitude  \
# 0  5086  98   2   3   1   1   2   2     0     0  ...   -1    4    4 -4.460442
# 1  1258  40   1   1   3   5   1   1     1     0  ...    4    1    4 -6.176438
# 2   331  18   2   4   6   3   2   1     0     0  ...   -1    1    1 -6.825702
# 3  6729  50   1   1   3   1   1   1     0     0  ...   -1    1    4 -3.372049
# 4  8671  34   1   1   1   1   2   1     0     1  ...   -1    1    4 -7.179645
#
#    Longitude  mobile_money  savings  borrowing  insurance  \
# 0  29.811396             0        0          0          0
# 1  39.244871             1        1          1          0
# 2  37.652798             1        0          0          0
# 3  35.808307             1        0          1          0
# 4  31.039095             1        1          0          1
#
#    mobile_money_classification
# 0                            0
# 1                            3
# 2                            2
# 3                            3
# 4                            3
#
# [5 rows x 37 columns]

# %% [markdown]
# #### Question 1. Make a scatter plot of the Longitude and Latitude columns

# %%
sns.set()
sns.relplot(x='Latitude', y='Longitude', data=df)

# %% [markdown]
# #### Question 2. Make a scatter plot of the Longitude and Latitude columns. This time, plot with 'hue' = Q2 and compare it over Q3

# %%
sns.relplot(x='Latitude', y='Longitude',hue='Q2', col='Q3', col_wrap=2, data=df)

# %% [markdown]
# #### Question 3. Make a boxplot of Longiture and Q2

# %%
sns.boxplot(x='Q2', y='Longitude', data=df)

# %% [markdown]
# #### Question 4. Make a count plot of all the cateegorical variables in the dataset.

# %%
df_cat = df.drop(['ID', 'Q1', 'Latitude', 'Longitude'], axis=1)

for col in df_cat.columns:
    sns.catplot(x=col, data=df_cat, kind='count')
